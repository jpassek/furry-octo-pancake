# %%
import pandas as pd
from scipy import stats

# %%
datafile = "/Users/justinpassek/Downloads/1800_Easter_T_NoFace_Face.csv"
df = pd.read_csv(datafile)

# %%
NoFace = df[df.Face == "No Face"]
print(NoFace)
Faces = df[df.Face == "Faces"]
print(Faces)
# Out:
#      Creative_ID  Clicks  Impressions  Active_View__Viewable_Impressions  \
# 0      113487492     270      1824188                             847383
# 1      110822591     745      1594717                             393396
# 2      110635914     767      1598039                             394088
# 3      113456872     328      1173687                             761023
# 4      113487495     171      1425305                             592508
# 5      111037917    1044      2873940                             772619
# 6      113468558      88       567197                             267554
# 7      113469986      84       569910                             269401
# 8      113470034      70       567824                             268667
# 9      110730839     678       651573                              16088
# 10     110755015     722       649875                              16294
# 11     113399950     100       402584                             256775
# ...

# %%
stats.ttest_ind(NoFace.Adj_V_CTR,Faces.Adj_V_CTR,equal_var = False)
# Out:
# Ttest_indResult(statistic=0.32061271855121265, pvalue=0.7490108138491307)
