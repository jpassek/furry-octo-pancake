# %%
import pandas as pd
from scipy import stats

# %%
datafile = "/Users/justinpassek/Downloads/1800_Easter_T_Arrangement.csv"
df = pd.read_csv(datafile)

# %%
print(df)
# Out:
#          C_id                                      Creative_Name  \
# 0   113225520  fy19_spring_freeshipnosvcchg_springtimevineyar...
# 1   106366936  fy19_newbaby_na_wonderfulwishes_productshot_30...
# 2   102489762  fy19_default_no-offer_floralembrace_productsho...
# 3   108294739  fy19_newbaby_na_wonderfulwishes_productshot_16...
# 4   107660963  fy19_smilefacts-bday_save15_trophybouquet_rose...
# 5    96580438  fy18_birthday_save15_dozenroses_closeupbdaywis...
# 6   108298078  fy19_newbaby_na_wonderfulwishes_productshot_30...
# 7   113470034  fy19_birthday_save15_birthyayflowercake_dotsan...
# 8   113201914  fy19_spring_freeshipnosvcchg_colorfultulipbulb...
# 9    99070375  fy19_birthday_save15_birthyayflowercake_dotsan...
# 10   99104106  fy19_birthday_save15_birthyayflowercake_dotsan...
# 11  102489753  fy19_default_no-offer_floralembrace_productsho...
# 12  113468537  fy19_spring_save15_colorfultulipbulbgarden_pro...
# ...

# %% [raw]
# Single = df[df.Arrangement == 'Single']
# print(Single)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-73d36ea8e164> in <module>()
# ----> 1 print(Single)
#
# NameError: name 'Single' is not defined

# %%
stats.ttest_ind(0.000643615,0.000818514, equal_var=False)
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3194: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Ttest_indResult(statistic=nan, pvalue=nan)
