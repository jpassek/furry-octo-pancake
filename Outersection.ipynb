# %%
import pandas as pd
from scipy import stats

# %%
datafile = "/Users/justinpassek/Downloads/1800_Easter_T_All.csv"
All = pd.read_csv(datafile)

# %%
datafile = "/Users/justinpassek/Downloads/results-20190513-143353.csv"
Faces = pd.read_csv(datafile)

# %%
No_Faces = set(All.C_id)^set(Faces.Creative_ID)

# %%
print len(No_Faces)
# Out:
#   File "<ipython-input-9-f02b094dd81b>", line 1
#     print len(No_Faces)
#             ^
# SyntaxError: invalid syntax

# %%
set(All.C_id)^set(Faces.Creative_ID)
# Out:
# {93394654,
#  93397390,
#  93411850,
#  93415318,
#  93491186,
#  94475359,
#  94476094,
#  94576616,
#  94589905,
#  94589911,
#  94644087,
#  94644090,
#  94674638,
#  95117325,
#  95118846,
#  95120103,
#  95149025,
#  95902979,
#  95995728,
#  96580438,
#  96581218,
#  96627390,
#  96628983,
#  96629292,
#  96629298,
#  96669980,
#  96673442,
#  97435474,
#  97496649,
#  97520659,
#  97520662,
#  97581831,
#  97582956,
#  97914196,
#  97973232,
#  98067167,
#  98896792,
#  98896795,
#  98897638,
#  98932701,
#  98932707,
#  99034097,
#  99070375,
#  99102984,
#  99104106,
#  99104109,
#  99104313,
#  99104316,
#  99274233,
#  99284079,
#  99285495,
#  99286275,
#  99386015,
#  99386024,
#  99388268,
#  99388271,
#  99388274,
#  99388520,
#  100565185,
#  100565188,
#  100590631,
#  100591573,
#  100592311,
#  100592524,
#  100598466,
#  100598469,
#  100598472,
#  100598487,
#  100599537,
#  100683014,
#  100683026,
#  100847374,
#  100847383,
#  100847386,
#  100847704,
# ...
