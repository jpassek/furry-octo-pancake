# %%
# Import libraries
import pandas as pd
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

datafile = "/Users/justinpassek/Downloads/home-values/single_family_home_values.csv"
df = pd.read_csv(datafile)

print(df)
# Out:
#               id                    address    city state  zipcode   latitude  \
# 0       39525749            8171 E 84th Ave  Denver    CO    80022  39.849160
# 1      184578398          10556 Wheeling St  Denver    CO    80022  39.888020
# 2      184430015        3190 Wadsworth Blvd  Denver    CO    80033  39.761710
# 3      155129946        3040 Wadsworth Blvd  Denver    CO    80033  39.760780
# 4         245107            5615 S Eaton St  Denver    CO    80123  39.616181
# ...          ...                        ...     ...   ...      ...        ...
# 14995   51411356              802 S High St  Denver    CO    80209  39.701902
# 14996   21721153           214 S Lincoln St  Denver    CO    80209  39.712608
# 14997   12995320              870 S Race St  Denver    CO    80209  39.700736
# 14998   39611615         130 S Lafayette St  Denver    CO    80209  39.714088
# 14999   42961679  100 S University Blvd # 1  Denver    CO    80209  39.714399
#
#         longitude  bedrooms  bathrooms  rooms  squareFootage  lotSize  \
# 0     -104.893468         3        2.0      6           1378     9968
# 1     -104.830930         2        2.0      6           1653     6970
# 2     -105.081070         3        1.0      0           1882    23875
# 3     -105.081060         4        3.0      0           2400    11500
# 4     -105.058812         3        4.0      8           2305     5600
# ...           ...       ...        ...    ...            ...      ...
# 14995 -104.964871         4        4.0      8           2169     4950
# 14996 -104.986000         3        3.0     11           2937     4500
# 14997 -104.963707         3        5.0      7           2937     4680
# 14998 -104.970701         3        4.0     10           3193     4970
# 14999 -104.958955         3        5.0      9           3193     4364
#
#        yearBuilt lastSaleDate  lastSaleAmount priorSaleDate  priorSaleAmount  \
# 0         2003.0   2009-12-17           75000    2004-05-13         165700.0
# 1         2004.0   2004-09-23          216935           NaN              NaN
# 2         1917.0   2008-04-03          330000           NaN              NaN
# 3         1956.0   2008-12-02          185000    2008-06-27              0.0
# 4         1998.0   2012-07-18          308000    2011-12-29              0.0
# ...          ...          ...             ...           ...              ...
# 14995     1922.0   2000-08-24          333000           NaN              NaN
# 14996     1890.0   2015-03-05          645000    2012-07-23         557500.0
# 14997     2007.0   2012-01-17         1115000    2008-07-15        1208214.0
# 14998     2005.0   2011-08-10         1350000    2004-12-07         405000.0
# 14999     2001.0   2014-05-29          960000    2003-07-11         925000.0
#
#        estimated_value
# 0               239753
# 1               343963
# 2               488840
# 3               494073
# 4               513676
# ...                ...
# 14995          1080081
# 14996           807306
# 14997          1737156
# 14998          2008794
# 14999          1421401
#
# [15000 rows x 18 columns]

# %%
#Build the dataframe for train data
train=df
train.drop(['id'], axis=1)
train_numerical = train.select_dtypes(exclude=['object'])
train_numerical.fillna(0,inplace = True)
train_categoric = train.select_dtypes(include=['object'])
train_categoric.fillna('NONE',inplace = True)
train = train_numerical.merge(train_categoric, left_index = True, right_index = True)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:4244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %%
#print(train)
train_numerical
# Out:
#               id  zipcode   latitude   longitude  bedrooms  bathrooms  rooms  \
# 0      184317294    80203  39.723117 -104.979622         2        2.0      9
# 1      184317293    80203  39.722664 -104.979487         1        1.0      4
# 2       21434098    80203  39.718147 -104.982445         3        3.0      8
# 3       49095774    80203  39.718671 -104.982940         3        2.0      6
# 4        4761930    80203  39.723054 -104.981460         2        2.0      7
# ...          ...      ...        ...         ...       ...        ...    ...
# 13495  184311569    80209  39.708452 -104.980694         3        2.0      8
# 13496   42985979    80209  39.698090 -104.976608         3        2.0      6
# 13497  150304831    80209  39.709681 -104.964860         3        2.0      7
# 13498   51411356    80209  39.701902 -104.964871         4        4.0      8
# 13499   21721153    80209  39.712608 -104.986000         3        3.0     11
#
#        squareFootage  lotSize  yearBuilt  lastSaleAmount  priorSaleAmount  \
# 0               1792     7813     1906.0          230000              0.0
# 1                770     1970     1933.0          378000         233000.0
# 2               1794     2079     1890.0          156000              0.0
# 3               1283     3970     1890.0          120000              0.0
# 4               1283     4690     1916.0          342000              0.0
# ...              ...      ...        ...             ...              ...
# 13495           1657     4690     1892.0           81800              0.0
# 13496           1913     4760     1909.0          600000         535000.0
# 13497           1913     4990     1925.0          815000         142000.0
# 13498           2169     4950     1922.0          333000              0.0
# 13499           2937     4500     1890.0          645000         557500.0
#
#        estimated_value
# 0               592298
# 1               420261
# 2               482596
# 3               510830
# 4               591506
# ...                ...
# 13495           632156
# 13496           694981
# 13497           784955
# 13498          1080081
# 13499           807306
#
# [13500 rows x 13 columns]

# %%
from sklearn.ensemble import IsolationForest
clf = IsolationForest(max_samples = 100, random_state = 42)
clf.fit(train_numerical)
y_noano = clf.predict(train_numerical)
y_noano = pd.DataFrame(y_noano, columns = ['Top'])
y_noano[y_noano['Top'] == 1].index.values
train_numerical = train_numerical.iloc[y_noano[y_noano['Top'] == 1].index.values]
train_numerical.reset_index(drop = True, inplace = True)
train_categoric = train_categoric.iloc[y_noano[y_noano['Top'] == 1].index.values]
train_categoric.reset_index(drop = True, inplace = True)
train = train.iloc[y_noano[y_noano['Top'] == 1].index.values]
train.reset_index(drop = True, inplace = True)
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
print(train)
# Out:
#               id  zipcode   latitude   longitude  bedrooms  bathrooms  rooms  \
# 0      184317294    80203  39.723117 -104.979622         2        2.0      9
# 1      184317293    80203  39.722664 -104.979487         1        1.0      4
# 2       21434098    80203  39.718147 -104.982445         3        3.0      8
# 3       49095774    80203  39.718671 -104.982940         3        2.0      6
# 4        4761930    80203  39.723054 -104.981460         2        2.0      7
# ...          ...      ...        ...         ...       ...        ...    ...
# 13495  184311569    80209  39.708452 -104.980694         3        2.0      8
# 13496   42985979    80209  39.698090 -104.976608         3        2.0      6
# 13497  150304831    80209  39.709681 -104.964860         3        2.0      7
# 13498   51411356    80209  39.701902 -104.964871         4        4.0      8
# 13499   21721153    80209  39.712608 -104.986000         3        3.0     11
#
#        squareFootage  lotSize  yearBuilt  lastSaleAmount  priorSaleAmount  \
# 0               1792     7813     1906.0          230000              0.0
# 1                770     1970     1933.0          378000         233000.0
# 2               1794     2079     1890.0          156000              0.0
# 3               1283     3970     1890.0          120000              0.0
# 4               1283     4690     1916.0          342000              0.0
# ...              ...      ...        ...             ...              ...
# 13495           1657     4690     1892.0           81800              0.0
# 13496           1913     4760     1909.0          600000         535000.0
# 13497           1913     4990     1925.0          815000         142000.0
# 13498           2169     4950     1922.0          333000              0.0
# 13499           2937     4500     1890.0          645000         557500.0
#
#        estimated_value                address    city state lastSaleDate  \
# 0               592298         432 N Pearl St  Denver    CO   1998-09-09
# 1               420261          617 E 4th Ave  Denver    CO   2014-12-18
# 2               482596          400 E 1st Ave  Denver    CO   1998-12-23
# 3               510830         119 N Logan St  Denver    CO   2001-08-20
# 4               591506  419 N Pennsylvania St  Denver    CO   2005-09-16
# ...                ...                    ...     ...   ...          ...
# 13495           632156         445 S Pearl St  Denver    CO   1998-04-08
# 13496           694981      1016 S Emerson St  Denver    CO   2017-05-31
# 13497           784955          376 S High St  Denver    CO   2015-09-10
# 13498          1080081          802 S High St  Denver    CO   2000-08-24
# 13499           807306       214 S Lincoln St  Denver    CO   2015-03-05
#
#       priorSaleDate
# 0              NONE
# 1        2012-04-26
# 2              NONE
# 3              NONE
# 4        2002-12-13
# ...             ...
# 13495          NONE
# 13496    2013-06-07
# 13497    1994-05-06
# 13498          NONE
# 13499    2012-07-23
#
# [13500 rows x 18 columns]

# %%
col_train_num = list(train_numerical.columns)
col_train_num_bis = list(train_numerical.columns)
col_train_cat = list(train_categoric.columns)
col_train_num_bis.remove('estimated_value')
mat_train = np.matrix(train_numerical)
mat_new = np.matrix(train_numerical.drop('estimated_value',axis = 1))
mat_y = np.array(train.estimated_value)
prepro_y = MinMaxScaler()
prepro_y.fit(mat_y.reshape(13500,1))
prepro = MinMaxScaler()
prepro.fit(mat_train)
prepro_test = MinMaxScaler()
prepro_test.fit(mat_new)
train_num_scale = pd.DataFrame(prepro.transform(mat_train),columns = col_train_num)
train[col_train_num] = pd.DataFrame(prepro.transform(mat_train),columns = col_train_num)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
train.head()
# Out:
#          id  zipcode  latitude  longitude  bedrooms  bathrooms     rooms  \
# 0  0.732640      0.0  0.998743   0.000697     0.250   0.333333  0.538462
# 1  0.732640      0.0  0.998732   0.000699     0.125   0.166667  0.153846
# 2  0.084694      0.0  0.998618   0.000670     0.375   0.500000  0.461538
# 3  0.194732      0.0  0.998631   0.000666     0.375   0.333333  0.307692
# 4  0.018373      0.0  0.998742   0.000680     0.250   0.333333  0.384615
#
#    squareFootage   lotSize  yearBuilt  lastSaleAmount  priorSaleAmount  \
# 0       0.370789  0.418826   0.225352        0.005038         0.000000
# 1       0.107997  0.068275   0.415493        0.008284         0.080289
# 2       0.371304  0.074814   0.112676        0.003415         0.000000
# 3       0.239907  0.188265   0.112676        0.002626         0.000000
# 4       0.239907  0.231461   0.295775        0.007494         0.000000
#
#    estimated_value                address    city state lastSaleDate  \
# 0         0.267997         432 N Pearl St  Denver    CO   1998-09-09
# 1         0.164280          617 E 4th Ave  Denver    CO   2014-12-18
# 2         0.201861          400 E 1st Ave  Denver    CO   1998-12-23
# 3         0.218882         119 N Logan St  Denver    CO   2001-08-20
# 4         0.267520  419 N Pennsylvania St  Denver    CO   2005-09-16
#
#   priorSaleDate
# 0          NONE
# 1    2012-04-26
# 2          NONE
# 3          NONE
# 4    2002-12-13

# %%
#train = train.drop(["id", "zipcode", "latitude","longitude","yearBuilt","lastSaleAmount","priorSaleAmount","priorSaleDate","address","city","state","lastSaleDate"], axis=1)
train.head()
# Out:
#          id  zipcode  latitude  longitude  bedrooms  bathrooms     rooms  \
# 0  0.732640      0.0  0.998743   0.000697     0.250   0.333333  0.538462
# 1  0.732640      0.0  0.998732   0.000699     0.125   0.166667  0.153846
# 2  0.084694      0.0  0.998618   0.000670     0.375   0.500000  0.461538
# 3  0.194732      0.0  0.998631   0.000666     0.375   0.333333  0.307692
# 4  0.018373      0.0  0.998742   0.000680     0.250   0.333333  0.384615
#
#    squareFootage   lotSize  yearBuilt  lastSaleAmount  priorSaleAmount  \
# 0       0.370789  0.418826   0.225352        0.005038         0.000000
# 1       0.107997  0.068275   0.415493        0.008284         0.080289
# 2       0.371304  0.074814   0.112676        0.003415         0.000000
# 3       0.239907  0.188265   0.112676        0.002626         0.000000
# 4       0.239907  0.231461   0.295775        0.007494         0.000000
#
#    estimated_value                address    city state lastSaleDate  \
# 0         0.267997         432 N Pearl St  Denver    CO   1998-09-09
# 1         0.164280          617 E 4th Ave  Denver    CO   2014-12-18
# 2         0.201861          400 E 1st Ave  Denver    CO   1998-12-23
# 3         0.218882         119 N Logan St  Denver    CO   2001-08-20
# 4         0.267520  419 N Pennsylvania St  Denver    CO   2005-09-16
#
#   priorSaleDate
# 0          NONE
# 1    2012-04-26
# 2          NONE
# 3          NONE
# 4    2002-12-13

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
COLUMNS = col_train_num
FEATURES = col_train_num_bis
LABEL = "estimated_value"
FEATURES_CAT = col_train_cat
engineered_features = []
for continuous_feature in FEATURES:
    engineered_features.append(
        tf.contrib.layers.real_valued_column(continuous_feature))
for categorical_feature in FEATURES_CAT:
    sparse_column = tf.contrib.layers.sparse_column_with_hash_bucket(
        categorical_feature, hash_bucket_size=1000)
engineered_features.append(tf.contrib.layers.embedding_column(sparse_id_column=sparse_column, dimension=16,combiner="sum"))
# Out:
# WARNING:tensorflow:The default stddev value of initializer was changed from "1/sqrt(vocab_size)" to "1/sqrt(dimension)" in core implementation (tf.feature_column.embedding_column).

# %%
# Build the training set and the prediction set
training_set = train[FEATURES + FEATURES_CAT]
prediction_set = train.estimated_value
# Split the train and prediction sets into test train sets
x_train, x_test, y_train, y_test = train_test_split(training_set[FEATURES + FEATURES_CAT] ,
                                                    prediction_set, test_size=0.2, random_state=42)
y_train = pd.DataFrame(y_train, columns = [LABEL])
training_set = pd.DataFrame(x_train, columns = FEATURES + FEATURES_CAT).merge(y_train, left_index = True, right_index = True)
y_test = pd.DataFrame(y_test, columns = [LABEL])
testing_set = pd.DataFrame(x_test, columns = FEATURES + FEATURES_CAT).merge(y_test, left_index = True, right_index = True)

# %%
training_set[FEATURES_CAT] = training_set[FEATURES_CAT].applymap(str)
testing_set[FEATURES_CAT] = testing_set[FEATURES_CAT].applymap(str)
def input_fn_new(data_set, training = True):
    continuous_cols = {k: tf.constant(data_set[k].values) for k in FEATURES}
    
    categorical_cols = {k: tf.SparseTensor(
        indices=[[i, 0] for i in range(data_set[k].size)], values = data_set[k].values, dense_shape = [data_set[k].size, 1]) for k in FEATURES_CAT}
# Combines the dictionaries of the categorical and continuous features
    feature_cols = dict(list(continuous_cols.items()) + list(categorical_cols.items()))
    
    if training == True:
        # Converts the label column into a constant Tensor.
        label = tf.constant(data_set[LABEL].values)
# Outputs the feature columns and labels
        return feature_cols, label
    
    return feature_cols
# Builds the Model Framework
regressor = tf.contrib.learn.DNNRegressor(feature_columns = engineered_features, 
                                          activation_fn = tf.nn.relu, hidden_units=[250, 100, 50])
categorical_cols = {k: tf.SparseTensor(indices=[[i, 0] for i in range(training_set[k].size)], values = training_set[k].values, dense_shape = [training_set[k].size, 1]) for k in FEATURES_CAT}
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/86/_yqzm45s4vjdjd84v10h6rt80000gn/T/tmpmjq4mb2l
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a2d190b38>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_protocol': None, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/var/folders/86/_yqzm45s4vjdjd84v10h6rt80000gn/T/tmpmjq4mb2l'}

# %%
regressor.fit(input_fn = lambda: input_fn_new(training_set) , steps=10000)
# Out:
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/86/_yqzm45s4vjdjd84v10h6rt80000gn/T/tmpmjq4mb2l/model.ckpt.
# INFO:tensorflow:loss = 0.08522309, step = 1
# INFO:tensorflow:global_step/sec: 32.5767
# INFO:tensorflow:loss = 0.0042600823, step = 101 (3.070 sec)
# INFO:tensorflow:global_step/sec: 34.0229
# INFO:tensorflow:loss = 0.0038871588, step = 201 (2.939 sec)
# INFO:tensorflow:global_step/sec: 34.0717
# INFO:tensorflow:loss = 0.0036740613, step = 301 (2.935 sec)
# INFO:tensorflow:global_step/sec: 34.0347
# INFO:tensorflow:loss = 0.0035413937, step = 401 (2.938 sec)
# INFO:tensorflow:global_step/sec: 34.0976
# INFO:tensorflow:loss = 0.003654762, step = 501 (2.933 sec)
# INFO:tensorflow:global_step/sec: 34.0868
# INFO:tensorflow:loss = 0.0034286832, step = 601 (2.934 sec)
# INFO:tensorflow:global_step/sec: 34.0422
# INFO:tensorflow:loss = 0.0033767468, step = 701 (2.937 sec)
# INFO:tensorflow:global_step/sec: 34.1509
# INFO:tensorflow:loss = 0.0034917137, step = 801 (2.928 sec)
# INFO:tensorflow:global_step/sec: 32.5083
# INFO:tensorflow:loss = 0.0033740636, step = 901 (3.076 sec)
# INFO:tensorflow:global_step/sec: 30.0931
# INFO:tensorflow:loss = 0.0032778422, step = 1001 (3.323 sec)
# INFO:tensorflow:global_step/sec: 33.3112
# INFO:tensorflow:loss = 0.003268694, step = 1101 (3.002 sec)
# INFO:tensorflow:global_step/sec: 33.2427
# INFO:tensorflow:loss = 0.0031998812, step = 1201 (3.008 sec)
# INFO:tensorflow:global_step/sec: 33.4088
# INFO:tensorflow:loss = 0.0031345903, step = 1301 (2.993 sec)
# INFO:tensorflow:global_step/sec: 33.5664
# INFO:tensorflow:loss = 0.0030868293, step = 1401 (2.980 sec)
# INFO:tensorflow:global_step/sec: 33.3218
# INFO:tensorflow:loss = 0.003071166, step = 1501 (3.001 sec)
# INFO:tensorflow:global_step/sec: 33.5303
# INFO:tensorflow:loss = 0.0030276976, step = 1601 (2.982 sec)
# INFO:tensorflow:global_step/sec: 33.3579
# INFO:tensorflow:loss = 0.0030150604, step = 1701 (2.998 sec)
# INFO:tensorflow:global_step/sec: 33.6454
# INFO:tensorflow:loss = 0.0029908367, step = 1801 (2.972 sec)
# INFO:tensorflow:global_step/sec: 33.1763
# INFO:tensorflow:loss = 0.0029720885, step = 1901 (3.014 sec)
# INFO:tensorflow:global_step/sec: 33.611
# INFO:tensorflow:loss = 0.0029418927, step = 2001 (2.975 sec)
# INFO:tensorflow:global_step/sec: 33.3166
# INFO:tensorflow:loss = 0.002914378, step = 2101 (3.002 sec)
# INFO:tensorflow:global_step/sec: 33.416
# INFO:tensorflow:loss = 0.0029048854, step = 2201 (2.993 sec)
# INFO:tensorflow:global_step/sec: 32.7327
# INFO:tensorflow:loss = 0.0028825398, step = 2301 (3.055 sec)
# INFO:tensorflow:global_step/sec: 33.3982
# INFO:tensorflow:loss = 0.002857232, step = 2401 (2.994 sec)
# INFO:tensorflow:global_step/sec: 31.7719
# INFO:tensorflow:loss = 0.0028360267, step = 2501 (3.147 sec)
# INFO:tensorflow:global_step/sec: 32.4218
# INFO:tensorflow:loss = 0.002828145, step = 2601 (3.085 sec)
# INFO:tensorflow:global_step/sec: 31.544
# INFO:tensorflow:loss = 0.0028094624, step = 2701 (3.170 sec)
# INFO:tensorflow:global_step/sec: 32.5065
# INFO:tensorflow:loss = 0.002796462, step = 2801 (3.076 sec)
# INFO:tensorflow:global_step/sec: 33.0313
# INFO:tensorflow:loss = 0.002770813, step = 2901 (3.028 sec)
# INFO:tensorflow:global_step/sec: 32.7907
# INFO:tensorflow:loss = 0.002776728, step = 3001 (3.049 sec)
# INFO:tensorflow:global_step/sec: 32.1721
# INFO:tensorflow:loss = 0.0027554734, step = 3101 (3.109 sec)
# INFO:tensorflow:global_step/sec: 32.2494
# INFO:tensorflow:loss = 0.0027410903, step = 3201 (3.101 sec)
# INFO:tensorflow:global_step/sec: 32.2959
# INFO:tensorflow:loss = 0.0027221597, step = 3301 (3.096 sec)
# INFO:tensorflow:global_step/sec: 32.7546
# INFO:tensorflow:loss = 0.0027231604, step = 3401 (3.053 sec)
# INFO:tensorflow:global_step/sec: 32.3926
# INFO:tensorflow:loss = 0.0026981807, step = 3501 (3.087 sec)
# INFO:tensorflow:global_step/sec: 32.2539
# INFO:tensorflow:loss = 0.0026954778, step = 3601 (3.100 sec)
# INFO:tensorflow:global_step/sec: 32.1932
# INFO:tensorflow:loss = 0.0026857462, step = 3701 (3.106 sec)
# INFO:tensorflow:global_step/sec: 32.3244
# INFO:tensorflow:loss = 0.00267511, step = 3801 (3.094 sec)
# INFO:tensorflow:global_step/sec: 32.2535
# INFO:tensorflow:loss = 0.0026842565, step = 3901 (3.100 sec)
# INFO:tensorflow:global_step/sec: 32.442
# INFO:tensorflow:loss = 0.0026570528, step = 4001 (3.083 sec)
# INFO:tensorflow:global_step/sec: 32.5263
# INFO:tensorflow:loss = 0.0026666932, step = 4101 (3.074 sec)
# INFO:tensorflow:global_step/sec: 32.4963
# INFO:tensorflow:loss = 0.0026425675, step = 4201 (3.077 sec)
# INFO:tensorflow:global_step/sec: 31.7186
# INFO:tensorflow:loss = 0.0026389405, step = 4301 (3.153 sec)
# INFO:tensorflow:global_step/sec: 29.23
# INFO:tensorflow:loss = 0.0026218991, step = 4401 (3.421 sec)
# INFO:tensorflow:global_step/sec: 31.1139
# INFO:tensorflow:loss = 0.0026102036, step = 4501 (3.214 sec)
# INFO:tensorflow:global_step/sec: 33.6992
# INFO:tensorflow:loss = 0.0026106152, step = 4601 (2.968 sec)
# INFO:tensorflow:global_step/sec: 34.2367
# INFO:tensorflow:loss = 0.002595708, step = 4701 (2.921 sec)
# INFO:tensorflow:global_step/sec: 30.7284
# INFO:tensorflow:loss = 0.0025948314, step = 4801 (3.254 sec)
# INFO:tensorflow:global_step/sec: 31.0503
# INFO:tensorflow:loss = 0.0025862618, step = 4901 (3.220 sec)
# INFO:tensorflow:global_step/sec: 32.6212
# INFO:tensorflow:loss = 0.002585971, step = 5001 (3.066 sec)
# INFO:tensorflow:global_step/sec: 34.2055
# INFO:tensorflow:loss = 0.0025740091, step = 5101 (2.923 sec)
# INFO:tensorflow:global_step/sec: 33.6334
# INFO:tensorflow:loss = 0.0025637585, step = 5201 (2.973 sec)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-f8b63a586e07> in <module>()
# ----> 1 regressor.fit(input_fn = lambda: input_fn_new(training_set) , steps=10000)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     486                 'in a future version' if date is None else ('after %s' % date),
#     487                 instructions)
# --> 488       return func(*args, **kwargs)
#     489     return tf_decorator.make_decorator(func, new_func, 'deprecated',
#     490                                        _add_deprecated_arg_notice_to_docstring(
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in fit(self, x, y, input_fn, steps, batch_size, monitors, max_steps)
#     523       hooks.append(basic_session_run_hooks.StopAtStepHook(steps, max_steps))
#     524
# --> 525     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#     526     logging.info('Loss for final step: %s.', loss)
#     527     return self
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in _train_model(self, input_fn, hooks)
#    1093         loss = None
#    1094         while not mon_sess.should_stop():
# -> 1095           _, loss = mon_sess.run([model_fn_ops.train_op, model_fn_ops.loss])
#    1096       return loss
#    1097
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     669                           feed_dict=feed_dict,
#     670                           options=options,
# --> 671                           run_metadata=run_metadata)
#     672
#     673   def run_step_fn(self, step_fn):
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1154                               feed_dict=feed_dict,
#    1155                               options=options,
# -> 1156                               run_metadata=run_metadata)
#    1157       except _PREEMPTION_ERRORS as e:
#    1158         logging.info('An error was raised. This may be due to a preemption in '
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1238   def run(self, *args, **kwargs):
#    1239     try:
# -> 1240       return self._sess.run(*args, **kwargs)
#    1241     except _PREEMPTION_ERRORS:
#    1242       raise
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1310                                   feed_dict=feed_dict,
#    1311                                   options=options,
# -> 1312                                   run_metadata=run_metadata)
#    1313
#    1314     for hook in self._hooks:
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1074
#    1075   def run(self, *args, **kwargs):
# -> 1076     return self._sess.run(*args, **kwargs)
#    1077
#    1078   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import matplotlib

ev = regressor.evaluate(input_fn=lambda: input_fn_new(testing_set, training = True), steps=1)
loss_score = ev["loss"]
print("Final Loss on the testing set: {0:f}".format(loss_score))

import matplotlib.pyplot as plt
import matplotlib
import itertools

ev = regressor.evaluate(input_fn=lambda: input_fn_new(testing_set, training = True), steps=1)
loss_score = ev["loss"]
print("Final Loss on the testing set: {0:f}".format(loss_score))
reality = pd.DataFrame(prepro.inverse_transform(testing_set.select_dtypes(exclude=['object'])), columns = [COLUMNS])['estimated_value']

y = regressor.predict(input_fn=lambda: input_fn_new(testing_set))
predictions = list(itertools.islice(y, testing_set.shape[0]))
predictions = pd.DataFrame(prepro_y.inverse_transform(np.array(predictions).reshape(2700,1)))

matplotlib.rc('xtick', labelsize=30) 
matplotlib.rc('ytick', labelsize=30)

fig, ax = plt.subplots(figsize=(15, 12))
plt.style.use('ggplot')
plt.plot(predictions.values, reality.values, 'ro')
plt.xlabel('Predictions', fontsize = 30)
plt.ylabel('Reality', fontsize = 30)
plt.title('Predictions x Reality on dataset Test', fontsize = 30)
ax.plot([reality.min(), reality.max()], [reality.min(), reality.max()], 'k--', lw=4)
plt.show()
# Out:
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# INFO:tensorflow:Starting evaluation at 2020-02-11-22:23:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/86/_yqzm45s4vjdjd84v10h6rt80000gn/T/tmpmjq4mb2l/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-02-11-22:23:39
# INFO:tensorflow:Saving dict for global step 0: global_step = 0, loss = 0.08548361
# Final Loss on the testing set: 0.085484
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# WARNING:tensorflow:Rank of input Tensor (1) should be the same as output_rank (2) for column. Will attempt to expand dims. It is highly recommended that you resize your input, as this behavior may change.
# INFO:tensorflow:Starting evaluation at 2020-02-11-22:23:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/86/_yqzm45s4vjdjd84v10h6rt80000gn/T/tmpmjq4mb2l/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-02-11-22:23:40
# INFO:tensorflow:Saving dict for global step 0: global_step = 0, loss = 0.08548361
# Final Loss on the testing set: 0.085484
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-6c9c101b6893> in <module>()
#      13 loss_score = ev["loss"]
#      14 print("Final Loss on the testing set: {0:f}".format(loss_score))
# ---> 15 reality = pd.DataFrame(prepro.inverse_transform(testing_set.select_dtypes(exclude=['object'])), columns = [COLUMNS])['estimated_value']
#      16
#      17 y = regressor.predict(input_fn=lambda: input_fn_new(testing_set))
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2956                 if self.columns.nlevels > 1:
#    2957                     return self._getitem_multilevel(key)
# -> 2958                 return self._get_item_cache(key)
#    2959
#    2960         # Do we have a slicer (on rows)?
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    3268         res = cache.get(item)
#    3269         if res is None:
# -> 3270             values = self._data.get(item)
#    3271             res = self._box_item_values(item, values)
#    3272             cache[item] = res
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in get(self, item)
#     958                         raise ValueError("cannot label index with a null key")
#     959
# --> 960             return self.iget(loc)
#     961         else:
#     962
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in iget(self, i)
#     975         Otherwise return as a ndarray
#     976         """
# --> 977         block = self.blocks[self._blknos[i]]
#     978         values = block.iget(self._blklocs[i])
#     979         if values.ndim != 1:
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
pd.DataFrame(prepro.inverse_transform(testing_set.select_dtypes(exclude=['object'])), columns = [['id',
 'zipcode',
 'latitude',
 'longitude',
 'bedrooms',
 'bathrooms',
 'rooms',
 'squareFootage',
 'lotSize',
 'yearBuilt',
 'lastSaleAmount',
 'priorSaleAmount',
 'estimated_value']]).estimated_value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-050f615276b0> in <module>()
#      11  'lastSaleAmount',
#      12  'priorSaleAmount',
# ---> 13  'estimated_value']]).estimated_value
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
# -> 5178                 return self[name]
#    5179             return object.__getattribute__(self, name)
#    5180
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2956                 if self.columns.nlevels > 1:
#    2957                     return self._getitem_multilevel(key)
# -> 2958                 return self._get_item_cache(key)
#    2959
#    2960         # Do we have a slicer (on rows)?
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    3268         res = cache.get(item)
#    3269         if res is None:
# -> 3270             values = self._data.get(item)
#    3271             res = self._box_item_values(item, values)
#    3272             cache[item] = res
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in get(self, item)
#     958                         raise ValueError("cannot label index with a null key")
#     959
# --> 960             return self.iget(loc)
#     961         else:
#     962
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in iget(self, i)
#     975         Otherwise return as a ndarray
#     976         """
# --> 977         block = self.blocks[self._blknos[i]]
#     978         values = block.iget(self._blklocs[i])
#     979         if values.ndim != 1:
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
col_train_num
# Out:
# ['id',
#  'zipcode',
#  'latitude',
#  'longitude',
#  'bedrooms',
#  'bathrooms',
#  'rooms',
#  'squareFootage',
#  'lotSize',
#  'yearBuilt',
#  'lastSaleAmount',
#  'priorSaleAmount',
#  'estimated_value']
